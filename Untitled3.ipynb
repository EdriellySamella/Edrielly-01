# %% [markdown]
# <a href="https://colab.research.google.com/github/EdriellySamella/Edrielly-01/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Calculadora de IMC (Índice de Massa Corporal)
def calcular_imc(peso, altura):
    imc = peso / (altura ** 2)
    return imc
#Verificador de Número Par ou Ímpar
def classificar_imc(imc):
    if imc < 18.5:
        return "Baixo peso"
    elif 18.5 <= imc < 25:
        return "Peso normal"
    elif 25 <= imc < 30:
        return "Sobrepeso"
    else:
        return "Obesidade"

def main():
    peso = float(input("Digite o seu peso em kg: "))
    altura = float(input("Digite a sua altura em metros: "))

    imc = calcular_imc(peso, altura)
    classificacao = classificar_imc(imc)

    print(f"Seu IMC é {imc:.2f}, o que indica {classificacao}.")

if __name__ == "__main__":
    main()
def verificar_par_ou_impar(numero):
    if numero % 2 == 0:
        return "par"
    else:
        return "ímpar"

numero = int(input("Digite um número inteiro: "))
resultado = verificar_par_ou_impar(numero)
print(f"O número {numero} é {resultado}.")
#Conversor de Temperatura
def converter_para_fahrenheit(celsius):
    fahrenheit = celsius * 9/5 + 32
    return fahrenheit

celsius = float(input("Digite a temperatura em Celsius: "))
fahrenheit = converter_para_fahrenheit(celsius)
print(f"A temperatura em Fahrenheit é: {fahrenheit}°F")
# Tabuada de Multiplicação
numero = int(input("Digite um número: "))
print(f"Tabuada de multiplicação de {numero}:")
for i in range(1, 11):
    print(f"{numero} x {i} = {numero * i}")

nota1 = float(input("Digite a primeira nota: "))
peso1 = float(input("Digite o peso da primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
peso2 = float(input("Digite o peso da segunda nota: "))
nota3 = float(input("Digite a terceira nota: "))
peso3 = float(input("Digite o peso da terceira nota: "))
#Cálculo de Média Ponderada
media_ponderada = (nota1 * peso1 + nota2 * peso2 + nota3 * peso3) / (peso1 + peso2 + peso3)
print(f"A média ponderada é: {media_ponderada}")

def verificar_bissexto(ano):
    if ano % 4 == 0 and (ano % 100 != 0 or ano % 400 == 0):
        return True
    else:
        return False
#Verificador de Ano Bissexto
ano = int(input("Digite um ano: "))
if verificar_bissexto(ano):
    print(f"O ano {ano} é bissexto.")
else:
    print(f"O ano {ano} não é bissexto.")
#Contador de Vogais em uma String
def contar_vogais(string):
    vogais = "aeiouAEIOU"
    contador = 0
    for char in string:
        if char in vogais:
            contador += 1
    return contador

string = input("Digite uma string: ")
num_vogais = contar_vogais(string)
print(f"A string contém {num_vogais} vogais.")
#Calculadora de Fatorial
def calcular_fatorial(numero):
    if numero == 0:
        return 1
    else:
        return numero * calcular_fatorial(numero - 1)

numero = int(input("Digite um número inteiro positivo: "))
fatorial = calcular_fatorial(numero)
print(f"O fatorial de {numero} é: {fatorial}")

inicio = int(input("Digite o número inicial do intervalo: "))
fim = int(input("Digite o número final do intervalo: "))
#Soma dos Números Pares em um Intervalo
soma_pares = 0
for i in range(inicio, fim + 1):
    if i % 2 == 0:
        soma_pares += i

print(f"A soma dos números pares no intervalo de {inicio} a {fim} é: {soma_pares}")
#Verificador de Número Primo
def verificar_primo(numero):
    if numero <= 1:
        return False
    for i in range(2, int(numero ** 0.5) + 1):
        if numero % i == 0:
            return False
    return True

numero = int(input("Digite um número inteiro positivo: "))
if verificar_primo(numero):
    print(f"O número {numero} é primo.")
else:
    print(f"O número {numero} não é primo.")
# Out:
# Digite o seu peso em kg: 50
# Digite a sua altura em metros: 1.60
# Seu IMC é 19.53, o que indica Peso normal.
# Digite um número inteiro: 2
# O número 2 é par.
# Digite a temperatura em Celsius: 39
# A temperatura em Fahrenheit é: 102.2°F
# Digite um número: 3
# Tabuada de multiplicação de 3:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# Digite a primeira nota: 10
# Digite o peso da primeira nota: 3
# Digite a segunda nota: 8
# Digite o peso da segunda nota: 4
# Digite a terceira nota: 8
# Digite o peso da terceira nota: 3
# A média ponderada é: 8.6
# Digite um ano: 2000
# O ano 2000 é bissexto.
# Digite uma string: vida
# A string contém 2 vogais.
# Digite um número inteiro positivo: 3
# O fatorial de 3 é: 6
# Digite o número inicial do intervalo: 4
# Digite o número final do intervalo: 8
# A soma dos números pares no intervalo de 4 a 8 é: 18
# Digite um número inteiro positivo: 2
# O número 2 é primo.
